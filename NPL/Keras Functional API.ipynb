# %% [markdown]
# # 1. Sequential API로 만든 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(3, input_dim=4, activation='softmax'))
# Out:
# 2023-01-16 21:10:32.630796: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 2. Functional API로 만든 모델

# %% [markdown]
# ### 1) 전결합 피드 포워드 신경망(Fully-connected FFNN)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# %%
inputs = Input(shape=(10,))

# %%
inputs = Input(shape=(10,))
hidden1 = Dense(64, activation='relu')(inputs)  # <- 새로 추가
hidden2 = Dense(64, activation='relu')(hidden1) # <- 새로 추가
output = Dense(1, activation='sigmoid')(hidden2) # <- 새로 추가

# %%
inputs = Input(shape=(10,))
hidden1 = Dense(64, activation='relu')(inputs)
hidden2 = Dense(64, activation='relu')(hidden1)
output = Dense(1, activation='sigmoid')(hidden2)
model = Model(inputs=inputs, outputs=output) # <- 새로 추가

# %% [markdown]
# 지금까지의 내용을 정리하면 다음과 같습니다.
#
# - Input() 함수에 입력의 크기를 정의합니다.
# - 이전층을 다음층 함수의 입력으로 사용하고, 변수에 할당합니다.
# - Model() 함수에 입력과 출력을 정의합니다.
#
# 이를 model로 저장하면 sequential API를 사용할 때와 마찬가지로 model.compile, model.fit 등을 사용 가능합니다.

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# model.fit(data, labels)

# 이번에는 변수명을 달리해서 FFNN을 만들어보겠습니다. 이번에는 은닉층과 출력층의 변수를 전부 x로 통일하였습니다.

# %%
inputs = Input(shape=(10,))
x = Dense(8, activation="relu")(inputs)
x = Dense(4, activation="relu")(x)
x = Dense(1, activation="linear")(x)
model = Model(inputs, x)

# %% [markdown]
# ### 2) 선형 회귀(Linear Regression)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model

X = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

inputs = Input(shape=(1,))
output = Dense(1, activation='linear')(inputs)
linear_model = Model(inputs, output)

sgd = optimizers.SGD(lr=0.01)

linear_model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
linear_model.fit(X, y, epochs=300)
# Out:
# /Users/seokholee/opt/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/300
# 1/1 [==============================] - 1s 883ms/step - loss: 4752.0181 - mse: 4752.0181
# Epoch 2/300
# 1/1 [==============================] - 0s 29ms/step - loss: 585.8482 - mse: 585.8482
# Epoch 3/300
# 1/1 [==============================] - 0s 20ms/step - loss: 73.2305 - mse: 73.2305
# Epoch 4/300
# 1/1 [==============================] - 0s 10ms/step - loss: 10.1550 - mse: 10.1550
# Epoch 5/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3922 - mse: 2.3922
# Epoch 6/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4354 - mse: 1.4354
# Epoch 7/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3159 - mse: 1.3159
# Epoch 8/300
# 1/1 [==============================] - 0s 31ms/step - loss: 1.2995 - mse: 1.2995
# Epoch 9/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2957 - mse: 1.2957
# Epoch 10/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2936 - mse: 1.2936
# Epoch 11/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2916 - mse: 1.2916
# Epoch 12/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2897 - mse: 1.2897
# Epoch 13/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2879 - mse: 1.2879
# Epoch 14/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2860 - mse: 1.2860
# Epoch 15/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.2841 - mse: 1.2841
# Epoch 16/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2823 - mse: 1.2823
# Epoch 17/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2805 - mse: 1.2805
# Epoch 18/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2787 - mse: 1.2787
# Epoch 19/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2769 - mse: 1.2769
# Epoch 20/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2751 - mse: 1.2751
# Epoch 21/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2733 - mse: 1.2733
# Epoch 22/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2716 - mse: 1.2716
# Epoch 23/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2698 - mse: 1.2698
# Epoch 24/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2681 - mse: 1.2681
# Epoch 25/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2664 - mse: 1.2664
# Epoch 26/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2647 - mse: 1.2647
# Epoch 27/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2630 - mse: 1.2630
# Epoch 28/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2614 - mse: 1.2614
# Epoch 29/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2597 - mse: 1.2597
# Epoch 30/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2581 - mse: 1.2581
# Epoch 31/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2565 - mse: 1.2565
# Epoch 32/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2548 - mse: 1.2548
# Epoch 33/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2532 - mse: 1.2532
# Epoch 34/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2517 - mse: 1.2517
# Epoch 35/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2501 - mse: 1.2501
# Epoch 36/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2485 - mse: 1.2485
# Epoch 37/300
# 1/1 [==============================] - 0s 68ms/step - loss: 1.2470 - mse: 1.2470
# Epoch 38/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2454 - mse: 1.2454
# Epoch 39/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2439 - mse: 1.2439
# Epoch 40/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2424 - mse: 1.2424
# Epoch 41/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2409 - mse: 1.2409
# Epoch 42/300
# 1/1 [==============================] - 0s 23ms/step - loss: 1.2394 - mse: 1.2394
# Epoch 43/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2380 - mse: 1.2380
# Epoch 44/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2365 - mse: 1.2365
# Epoch 45/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2351 - mse: 1.2351
# Epoch 46/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2336 - mse: 1.2336
# Epoch 47/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2322 - mse: 1.2322
# Epoch 48/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2308 - mse: 1.2308
# Epoch 49/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2294 - mse: 1.2294
# Epoch 50/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2280 - mse: 1.2280
# Epoch 51/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2266 - mse: 1.2266
# Epoch 52/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2252 - mse: 1.2252
# Epoch 53/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2239 - mse: 1.2239
# Epoch 54/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2225 - mse: 1.2225
# Epoch 55/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2212 - mse: 1.2212
# Epoch 56/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2199 - mse: 1.2199
# Epoch 57/300
# 1/1 [==============================] - 0s 21ms/step - loss: 1.2186 - mse: 1.2186
# Epoch 58/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2173 - mse: 1.2173
# Epoch 59/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2160 - mse: 1.2160
# Epoch 60/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2147 - mse: 1.2147
# Epoch 61/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2134 - mse: 1.2134
# Epoch 62/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2122 - mse: 1.2122
# Epoch 63/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2109 - mse: 1.2109
# Epoch 64/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.2097 - mse: 1.2097
# Epoch 65/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2085 - mse: 1.2085
# Epoch 66/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2072 - mse: 1.2072
# Epoch 67/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2060 - mse: 1.2060
# Epoch 68/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2048 - mse: 1.2048
# Epoch 69/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2037 - mse: 1.2037
# Epoch 70/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2025 - mse: 1.2025
# Epoch 71/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2013 - mse: 1.2013
# Epoch 72/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2001 - mse: 1.2001
# Epoch 73/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1990 - mse: 1.1990
# Epoch 74/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1979 - mse: 1.1979
# Epoch 75/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1967 - mse: 1.1967
# Epoch 76/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1956 - mse: 1.1956
# Epoch 77/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1945 - mse: 1.1945
# Epoch 78/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1934 - mse: 1.1934
# Epoch 79/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1923 - mse: 1.1923
# Epoch 80/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1912 - mse: 1.1912
# Epoch 81/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1901 - mse: 1.1901
# Epoch 82/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1891 - mse: 1.1891
# Epoch 83/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1880 - mse: 1.1880
# Epoch 84/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1870 - mse: 1.1870
# Epoch 85/300
# 1/1 [==============================] - 0s 22ms/step - loss: 1.1859 - mse: 1.1859
# Epoch 86/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1849 - mse: 1.1849
# Epoch 87/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1839 - mse: 1.1839
# Epoch 88/300
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1828 - mse: 1.1828
# Epoch 89/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1818 - mse: 1.1818
# Epoch 90/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1808 - mse: 1.1808
# Epoch 91/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1798 - mse: 1.1798
# Epoch 92/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1789 - mse: 1.1789
# Epoch 93/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1779 - mse: 1.1779
# Epoch 94/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1769 - mse: 1.1769
# Epoch 95/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1760 - mse: 1.1760
# Epoch 96/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1750 - mse: 1.1750
# Epoch 97/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1741 - mse: 1.1741
# Epoch 98/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1731 - mse: 1.1731
# Epoch 99/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1722 - mse: 1.1722
# Epoch 100/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1713 - mse: 1.1713
# Epoch 101/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1704 - mse: 1.1704
# Epoch 102/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1695 - mse: 1.1695
# Epoch 103/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1686 - mse: 1.1686
# Epoch 104/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1677 - mse: 1.1677
# Epoch 105/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1668 - mse: 1.1668
# Epoch 106/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1659 - mse: 1.1659
# Epoch 107/300
# 1/1 [==============================] - 0s 42ms/step - loss: 1.1650 - mse: 1.1650
# Epoch 108/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1642 - mse: 1.1642
# Epoch 109/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1633 - mse: 1.1633
# Epoch 110/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1625 - mse: 1.1625
# Epoch 111/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1616 - mse: 1.1616
# Epoch 112/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1608 - mse: 1.1608
# Epoch 113/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1600 - mse: 1.1600
# Epoch 114/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1591 - mse: 1.1591
# Epoch 115/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1583 - mse: 1.1583
# Epoch 116/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1575 - mse: 1.1575
# Epoch 117/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1567 - mse: 1.1567
# Epoch 118/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1559 - mse: 1.1559
# Epoch 119/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1551 - mse: 1.1551
# Epoch 120/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1544 - mse: 1.1544
# Epoch 121/300
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1536 - mse: 1.1536
# Epoch 122/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1528 - mse: 1.1528
# Epoch 123/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1521 - mse: 1.1521
# Epoch 124/300
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1513 - mse: 1.1513
# Epoch 125/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1505 - mse: 1.1505
# Epoch 126/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1498 - mse: 1.1498
# Epoch 127/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1491 - mse: 1.1491
# Epoch 128/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1483 - mse: 1.1483
# Epoch 129/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1476 - mse: 1.1476
# Epoch 130/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1469 - mse: 1.1469
# Epoch 131/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1462 - mse: 1.1462
# Epoch 132/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1455 - mse: 1.1455
# Epoch 133/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1448 - mse: 1.1448
# Epoch 134/300
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1441 - mse: 1.1441
# Epoch 135/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1434 - mse: 1.1434
# Epoch 136/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1427 - mse: 1.1427
# Epoch 137/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1420 - mse: 1.1420
# Epoch 138/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1413 - mse: 1.1413
# Epoch 139/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1407 - mse: 1.1407
# Epoch 140/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1400 - mse: 1.1400
# Epoch 141/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1394 - mse: 1.1394
# Epoch 142/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1387 - mse: 1.1387
# Epoch 143/300
# 1/1 [==============================] - 0s 52ms/step - loss: 1.1381 - mse: 1.1381
# Epoch 144/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1374 - mse: 1.1374
# Epoch 145/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1368 - mse: 1.1368
# Epoch 146/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1362 - mse: 1.1362
# Epoch 147/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1355 - mse: 1.1355
# Epoch 148/300
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1349 - mse: 1.1349
# Epoch 149/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1343 - mse: 1.1343
# Epoch 150/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1337 - mse: 1.1337
# Epoch 151/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1331 - mse: 1.1331
# Epoch 152/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1325 - mse: 1.1325
# Epoch 153/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1319 - mse: 1.1319
# Epoch 154/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1313 - mse: 1.1313
# Epoch 155/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1307 - mse: 1.1307
# Epoch 156/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1301 - mse: 1.1301
# Epoch 157/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1296 - mse: 1.1296
# Epoch 158/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1290 - mse: 1.1290
# Epoch 159/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1284 - mse: 1.1284
# Epoch 160/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1279 - mse: 1.1279
# Epoch 161/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1273 - mse: 1.1273
# Epoch 162/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1267 - mse: 1.1267
# Epoch 163/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1262 - mse: 1.1262
# Epoch 164/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1256 - mse: 1.1256
# Epoch 165/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1251 - mse: 1.1251
# Epoch 166/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1246 - mse: 1.1246
# Epoch 167/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1240 - mse: 1.1240
# Epoch 168/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1235 - mse: 1.1235
# Epoch 169/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1230 - mse: 1.1230
# Epoch 170/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1225 - mse: 1.1225
# Epoch 171/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1220 - mse: 1.1220
# Epoch 172/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1215 - mse: 1.1215
# Epoch 173/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1210 - mse: 1.1210
# Epoch 174/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1205 - mse: 1.1205
# Epoch 175/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1200 - mse: 1.1200
# Epoch 176/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1195 - mse: 1.1195
# Epoch 177/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1190 - mse: 1.1190
# Epoch 178/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1185 - mse: 1.1185
# Epoch 179/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1180 - mse: 1.1180
# Epoch 180/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1175 - mse: 1.1175
# Epoch 181/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1171 - mse: 1.1171
# Epoch 182/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1166 - mse: 1.1166
# Epoch 183/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1161 - mse: 1.1161
# Epoch 184/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1157 - mse: 1.1157
# Epoch 185/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1152 - mse: 1.1152
# Epoch 186/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1148 - mse: 1.1148
# Epoch 187/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1143 - mse: 1.1143
# Epoch 188/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1139 - mse: 1.1139
# Epoch 189/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1134 - mse: 1.1134
# Epoch 190/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1130 - mse: 1.1130
# Epoch 191/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1125 - mse: 1.1125
# Epoch 192/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1121 - mse: 1.1121
# Epoch 193/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1117 - mse: 1.1117
# Epoch 194/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1113 - mse: 1.1113
# Epoch 195/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1108 - mse: 1.1108
# Epoch 196/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1104 - mse: 1.1104
# Epoch 197/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1100 - mse: 1.1100
# Epoch 198/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1096 - mse: 1.1096
# Epoch 199/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1092 - mse: 1.1092
# Epoch 200/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1088 - mse: 1.1088
# Epoch 201/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1084 - mse: 1.1084
# Epoch 202/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1080 - mse: 1.1080
# Epoch 203/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1076 - mse: 1.1076
# Epoch 204/300
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1072 - mse: 1.1072
# Epoch 205/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1068 - mse: 1.1068
# Epoch 206/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1064 - mse: 1.1064
# Epoch 207/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1060 - mse: 1.1060
# Epoch 208/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1057 - mse: 1.1057
# Epoch 209/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1053 - mse: 1.1053
# Epoch 210/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1049 - mse: 1.1049
# Epoch 211/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1045 - mse: 1.1045
# Epoch 212/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1042 - mse: 1.1042
# Epoch 213/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1038 - mse: 1.1038
# Epoch 214/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1035 - mse: 1.1035
# Epoch 215/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1031 - mse: 1.1031
# Epoch 216/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1027 - mse: 1.1027
# Epoch 217/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1024 - mse: 1.1024
# Epoch 218/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1020 - mse: 1.1020
# Epoch 219/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1017 - mse: 1.1017
# Epoch 220/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1014 - mse: 1.1014
# Epoch 221/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1010 - mse: 1.1010
# Epoch 222/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1007 - mse: 1.1007
# Epoch 223/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1003 - mse: 1.1003
# Epoch 224/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1000 - mse: 1.1000
# Epoch 225/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0997 - mse: 1.0997
# Epoch 226/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0994 - mse: 1.0994
# Epoch 227/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0990 - mse: 1.0990
# Epoch 228/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0987 - mse: 1.0987
# Epoch 229/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0984 - mse: 1.0984
# Epoch 230/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0981 - mse: 1.0981
# Epoch 231/300
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0978 - mse: 1.0978
# Epoch 232/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0975 - mse: 1.0975
# Epoch 233/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0971 - mse: 1.0971
# Epoch 234/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0968 - mse: 1.0968
# Epoch 235/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0965 - mse: 1.0965
# Epoch 236/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0962 - mse: 1.0962
# Epoch 237/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0959 - mse: 1.0959
# Epoch 238/300
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0956 - mse: 1.0956
# Epoch 239/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0954 - mse: 1.0954
# Epoch 240/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0951 - mse: 1.0951
# Epoch 241/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0948 - mse: 1.0948
# Epoch 242/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0945 - mse: 1.0945
# Epoch 243/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0942 - mse: 1.0942
# Epoch 244/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0939 - mse: 1.0939
# Epoch 245/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0936 - mse: 1.0936
# Epoch 246/300
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0934 - mse: 1.0934
# Epoch 247/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0931 - mse: 1.0931
# Epoch 248/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0928 - mse: 1.0928
# Epoch 249/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0925 - mse: 1.0925
# Epoch 250/300
# 1/1 [==============================] - 0s 85ms/step - loss: 1.0923 - mse: 1.0923
# Epoch 251/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0920 - mse: 1.0920
# Epoch 252/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0918 - mse: 1.0918
# Epoch 253/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0915 - mse: 1.0915
# Epoch 254/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0912 - mse: 1.0912
# Epoch 255/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0910 - mse: 1.0910
# Epoch 256/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0907 - mse: 1.0907
# Epoch 257/300
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0905 - mse: 1.0905
# Epoch 258/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0902 - mse: 1.0902
# Epoch 259/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0900 - mse: 1.0900
# Epoch 260/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0897 - mse: 1.0897
# Epoch 261/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0895 - mse: 1.0895
# Epoch 262/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0892 - mse: 1.0892
# Epoch 263/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0890 - mse: 1.0890
# Epoch 264/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0888 - mse: 1.0888
# Epoch 265/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0885 - mse: 1.0885
# Epoch 266/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0883 - mse: 1.0883
# Epoch 267/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0880 - mse: 1.0880
# Epoch 268/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0878 - mse: 1.0878
# Epoch 269/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0876 - mse: 1.0876
# Epoch 270/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0874 - mse: 1.0874
# Epoch 271/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0871 - mse: 1.0871
# Epoch 272/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0869 - mse: 1.0869
# Epoch 273/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0867 - mse: 1.0867
# Epoch 274/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0865 - mse: 1.0865
# Epoch 275/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0863 - mse: 1.0863
# Epoch 276/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0860 - mse: 1.0860
# Epoch 277/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0858 - mse: 1.0858
# Epoch 278/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0856 - mse: 1.0856
# Epoch 279/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0854 - mse: 1.0854
# Epoch 280/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0852 - mse: 1.0852
# Epoch 281/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0850 - mse: 1.0850
# Epoch 282/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0848 - mse: 1.0848
# Epoch 283/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0846 - mse: 1.0846
# Epoch 284/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0844 - mse: 1.0844
# Epoch 285/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0842 - mse: 1.0842
# Epoch 286/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0840 - mse: 1.0840
# Epoch 287/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0838 - mse: 1.0838
# Epoch 288/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0836 - mse: 1.0836
# Epoch 289/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0834 - mse: 1.0834
# Epoch 290/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0832 - mse: 1.0832
# Epoch 291/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0830 - mse: 1.0830
# Epoch 292/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0828 - mse: 1.0828
# Epoch 293/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0826 - mse: 1.0826
# Epoch 294/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0824 - mse: 1.0824
# Epoch 295/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0823 - mse: 1.0823
# Epoch 296/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0821 - mse: 1.0821
# Epoch 297/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0819 - mse: 1.0819
# Epoch 298/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0817 - mse: 1.0817
# Epoch 299/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0815 - mse: 1.0815
# Epoch 300/300
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0813 - mse: 1.0813

# %% [markdown]
# ### 3) 로지스틱 회귀(Logistic Regression)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

inputs = Input(shape=(3,))
output = Dense(1, activation='sigmoid')(inputs)
logistic_model = Model(inputs, output)

# %% [markdown]
# ### 4) 다중 입력을 받는 모델(model that accepts multiple inputs)

# %%
# 최종 완성된 다중 입력, 다중 출력 모델의 예
#model = Model(inputs=[a1, a2], outputs=[b1, b2, b3])

# %%
from tensorflow.keras.layers import Input, Dense, concatenate
from tensorflow.keras.models import Model

# 두 개의 입력층을 정의
inputA = Input(shape=(64,))
inputB = Input(shape=(128,))

# 첫번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
x = Dense(16, activation="relu")(inputA)
x = Dense(8, activation="relu")(x)
x = Model(inputs=inputA, outputs=x)

# 두번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
y = Dense(64, activation="relu")(inputB)
y = Dense(32, activation="relu")(y)
y = Dense(8, activation="relu")(y)
y = Model(inputs=inputB, outputs=y)

# 두개의 인공 신경망의 출력을 연결(concatenate)
result = concatenate([x.output, y.output])

z = Dense(2, activation="relu")(result)
z = Dense(1, activation="linear")(z)

model = Model(inputs=[x.input, y.input], outputs=z)

# %% [markdown]
# ### 5) RNN(Recurrence Neural Network) 은닉층 사용하기

# %%
from tensorflow.keras.layers import Input, Dense, LSTM
from tensorflow.keras.models import Model

inputs = Input(shape=(50,1))
lstm_layer = LSTM(10)(inputs)
x = Dense(10, activation='relu')(lstm_layer)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### 6) 다르게 보이지만 동일한 표기

# %%
result = Dense(128)(input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jt/jw2pb8hx71d48w0rx0cgqf_80000gn/T/ipykernel_6026/3881384629.py in <module>
# ----> 1 result = Dense(128)(input)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     195     # have a `shape` attribute.
#     196     if not hasattr(x, 'shape'):
# --> 197       raise TypeError(f'Inputs to a layer should be tensors. Got: {x}')
#     198
#     199   if len(inputs) != len(input_spec):
#
# TypeError: Inputs to a layer should be tensors. Got: <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fcdfd2c8fa0>>

# %%
dense = Dense(128)
result = dense(input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jt/jw2pb8hx71d48w0rx0cgqf_80000gn/T/ipykernel_6026/403454119.py in <module>
#       1 dense = Dense(128)
# ----> 2 result = dense(input)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     195     # have a `shape` attribute.
#     196     if not hasattr(x, 'shape'):
# --> 197       raise TypeError(f'Inputs to a layer should be tensors. Got: {x}')
#     198
#     199   if len(inputs) != len(input_spec):
#
# TypeError: Inputs to a layer should be tensors. Got: <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fcdfd2c8fa0>>
